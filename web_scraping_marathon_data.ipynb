# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
urlbase_2019 = 'https://api.competitor.com/public/result/subevent/622BBEE3-D94F-E811-941E-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip='
urlbase_2018 = 'https://api.competitor.com/public/result/subevent/DEDEEE82-E676-E711-9418-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip='
urlbase_2017 = 'https://api.competitor.com/public/result/subevent/9D1CE788-E676-E711-9418-005056951BF1?$limit=50&$sort[FinishRankOverall]=1&$skip='

# %%
pgs_2019 = 57
pgs_2018 = 43
pgs_2017 = 74

# %%
page_counter = 0
item_counter = 0
data = []
def get_data(url,num_pgs):
    global page_counter, item_counter
    #contains the url with the added skip number
    url_skip_num = url + str(item_counter)
    response = requests.get(url_skip_num, headers = {'WTC_PRIV_KEY': '90da38d91a0648f89823e375a43b2dc8'}).json()
    #looping over the tuples: total, limit, skip, data
    for item in response.items():
        #if tuple is equal to data
        if item[0] == 'data':
            #loop over data
            for i in item[1]:
                #add to global list
                data.append(i)
                item_counter += 1
    if page_counter != num_pgs:
        page_counter += 1
        #calling get_data until all pages have been counted
        get_data(url, num_pgs)
        
            
        
get_data(urlbase_2017,pgs_2017)
marathon2017 = pd.DataFrame(data)

# %%
marathon2017.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:40:25          00:00:00          00:00:00             2:40:25
# 1          2:56:28          00:00:00          00:00:00             2:56:28
# 2          3:00:55          00:00:00          00:00:00             3:00:55
# 3          3:04:47          00:00:00          00:00:00             3:04:47
# 4          3:04:53          00:00:00          00:00:00             3:04:53
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2017 Rock 'n' Roll Nashville Marathon
# 1  2017 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2017.tail()
# Out:
#      RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 3646         00:00:00          00:00:00          00:00:00            00:00:00
# 3647         00:00:00          00:00:00          00:00:00            00:00:00
# 3648         00:00:00          00:00:00          00:00:00            00:00:00
# 3649          3:13:08          00:00:00          00:00:00             3:13:08
# 3650         00:00:00          00:00:00          00:00:00            00:00:00
#
#      Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 3646                 00:00:00                 00:00:00          US
# 3647                 00:00:00                 00:00:00          US
# 3648                 00:00:00                 00:00:00          US
# 3649                 00:00:00                 00:00:00          US
# 3650                 00:00:00                 00:00:00          US
#
#                                SubeventName  \
# 3646  2017 Rock 'n' Roll Nashville Marathon
# ...

# %%
#resetting the counter for get_data function for year 2018
page_counter = 0
item_counter = 0
data = []
get_data(urlbase_2018,pgs_2018)
marathon2018 = pd.DataFrame(data)

# %%
marathon2018.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:28:16          00:00:00          00:00:00             2:28:16
# 1          2:29:52          00:00:00          00:00:00             2:29:52
# 2          2:38:59          00:00:00          00:00:00             2:38:59
# 3          2:43:59          00:00:00          00:00:00             2:43:59
# 4          2:48:11          00:00:00          00:00:00             2:48:11
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2018 Rock 'n' Roll Nashville Marathon
# 1  2018 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2018.tail()
# Out:
#      RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 2110         00:00:00          00:00:00          00:00:00            00:00:00
# 2111         00:00:00          00:00:00          00:00:00            00:00:00
# 2112         00:00:00          00:00:00          00:00:00            00:00:00
# 2113         00:00:00          00:00:00          00:00:00            00:00:00
# 2114         00:00:00          00:00:00          00:00:00            00:00:00
#
#      Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 2110                 00:00:00                 00:00:00          US
# 2111                 00:00:00                 00:00:00          US
# 2112                 00:00:00                 00:00:00          US
# 2113                 00:00:00                 00:00:00          US
# 2114                 00:00:00                 00:00:00          US
#
#                                SubeventName  \
# 2110  2018 Rock 'n' Roll Nashville Marathon
# ...

# %%
#resetting the counter for get_data function for year 2019
page_counter = 0
item_counter = 0
data = []
get_data(urlbase_2019,pgs_2019)
marathon2019 = pd.DataFrame(data)

# %%
marathon2019.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          1:37:54          00:00:00          00:00:00             1:37:54
# 1          2:34:59          00:00:00          00:00:00             2:34:59
# 2          2:35:24          00:00:00          00:00:00             2:35:24
# 3          2:39:59          00:00:00          00:00:00             2:39:59
# 4          2:42:09          00:00:00          00:00:00             2:42:09
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2019 Rock 'n' Roll Nashville Marathon
# 1  2019 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2019.tail()
# Out:
#      RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 2806         00:00:00          00:00:00          00:00:00            00:00:00
# 2807         00:00:00          00:00:00          00:00:00            00:00:00
# 2808         00:00:00          00:00:00          00:00:00            00:00:00
# 2809         00:00:00          00:00:00          00:00:00            00:00:00
# 2810         00:00:00          00:00:00          00:00:00            00:00:00
#
#      Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 2806                 00:00:00                 00:00:00          US
# 2807                 00:00:00                 00:00:00          US
# 2808                 00:00:00                 00:00:00          US
# 2809                 00:00:00                 00:00:00          US
# 2810                 00:00:00                 00:00:00          US
#
#                                SubeventName  \
# 2806  2019 Rock 'n' Roll Nashville Marathon
# ...

# %% [markdown]
# for item in marathon2017['Contact'].items():
#     print(item)
#     print(type(item))

# %% [markdown]
# for item in marathon2017['Contact'].items():
#     print(item[1]['FullName']+': '+item[1]['Gender'])

# %%
def new_contact(df):
    contact_list = []
    for item in df['Contact'].items():
            full_name = 'Full Name: '+ item[1]['FullName'].title()
            gender = 'Gender: ' + str(item[1]['Gender'])
            contact = full_name+' '+gender
            contact_list.append(contact)
    return contact_list

# %%
marathon2017['Contact'] = new_contact(marathon2017)
marathon2017.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:40:25          00:00:00          00:00:00             2:40:25
# 1          2:56:28          00:00:00          00:00:00             2:56:28
# 2          3:00:55          00:00:00          00:00:00             3:00:55
# 3          3:04:47          00:00:00          00:00:00             3:04:47
# 4          3:04:53          00:00:00          00:00:00             3:04:53
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2017 Rock 'n' Roll Nashville Marathon
# 1  2017 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2018['Contact'] = new_contact(marathon2018)
marathon2018.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:28:16          00:00:00          00:00:00             2:28:16
# 1          2:29:52          00:00:00          00:00:00             2:29:52
# 2          2:38:59          00:00:00          00:00:00             2:38:59
# 3          2:43:59          00:00:00          00:00:00             2:43:59
# 4          2:48:11          00:00:00          00:00:00             2:48:11
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2018 Rock 'n' Roll Nashville Marathon
# 1  2018 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2019['Contact'] = new_contact(marathon2019)
marathon2019.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          1:37:54          00:00:00          00:00:00             1:37:54
# 1          2:34:59          00:00:00          00:00:00             2:34:59
# 2          2:35:24          00:00:00          00:00:00             2:35:24
# 3          2:39:59          00:00:00          00:00:00             2:39:59
# 4          2:42:09          00:00:00          00:00:00             2:42:09
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2019 Rock 'n' Roll Nashville Marathon
# 1  2019 Rock 'n' Roll Nashville Marathon
# ...

# %% [markdown]
# for item in marathon2017['Country'].items():
#         print(item)
#         print(type(item))

# %%
def new_country(df):
    country_abb_list = []
    for item in df['Country'].items():
            country_abb = 'ISO2: ' + str(item[1]['ISO2'])
            country_abb_list.append(country_abb)
    return country_abb_list

# %%
marathon2017['Country'] = new_country(marathon2017)
marathon2017.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:40:25          00:00:00          00:00:00             2:40:25
# 1          2:56:28          00:00:00          00:00:00             2:56:28
# 2          3:00:55          00:00:00          00:00:00             3:00:55
# 3          3:04:47          00:00:00          00:00:00             3:04:47
# 4          3:04:53          00:00:00          00:00:00             3:04:53
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2017 Rock 'n' Roll Nashville Marathon
# 1  2017 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2018['Country'] = new_country(marathon2018)
marathon2018.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:28:16          00:00:00          00:00:00             2:28:16
# 1          2:29:52          00:00:00          00:00:00             2:29:52
# 2          2:38:59          00:00:00          00:00:00             2:38:59
# 3          2:43:59          00:00:00          00:00:00             2:43:59
# 4          2:48:11          00:00:00          00:00:00             2:48:11
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2018 Rock 'n' Roll Nashville Marathon
# 1  2018 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2019['Country'] = new_country(marathon2019)
marathon2019.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          1:37:54          00:00:00          00:00:00             1:37:54
# 1          2:34:59          00:00:00          00:00:00             2:34:59
# 2          2:35:24          00:00:00          00:00:00             2:35:24
# 3          2:39:59          00:00:00          00:00:00             2:39:59
# 4          2:42:09          00:00:00          00:00:00             2:42:09
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2019 Rock 'n' Roll Nashville Marathon
# 1  2019 Rock 'n' Roll Nashville Marathon
# ...

# %% [markdown]
# for item in marathon2017['Subevent'].items():
#          print(item)
#          print(type(item))

# %%
def new_subevent(df):
    subevent_list = []
    for item in df['Subevent'].items():
             event = 'SubEvent: '+str(item[1]['SubEvent'])
             subevent_list.append(event)
    return subevent_list

# %%
marathon2017['Subevent'] = new_subevent(marathon2017)
marathon2017.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:40:25          00:00:00          00:00:00             2:40:25
# 1          2:56:28          00:00:00          00:00:00             2:56:28
# 2          3:00:55          00:00:00          00:00:00             3:00:55
# 3          3:04:47          00:00:00          00:00:00             3:04:47
# 4          3:04:53          00:00:00          00:00:00             3:04:53
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2017 Rock 'n' Roll Nashville Marathon
# 1  2017 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2018['Subevent'] = new_subevent(marathon2018)
marathon2018.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          2:28:16          00:00:00          00:00:00             2:28:16
# 1          2:29:52          00:00:00          00:00:00             2:29:52
# 2          2:38:59          00:00:00          00:00:00             2:38:59
# 3          2:43:59          00:00:00          00:00:00             2:43:59
# 4          2:48:11          00:00:00          00:00:00             2:48:11
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2018 Rock 'n' Roll Nashville Marathon
# 1  2018 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2019['Subevent'] = new_subevent(marathon2019)
marathon2019.head()
# Out:
#   RunTimeConverted SwimTimeConverted BikeTimeConverted FinishTimeConverted  \
# 0          1:37:54          00:00:00          00:00:00             1:37:54
# 1          2:34:59          00:00:00          00:00:00             2:34:59
# 2          2:35:24          00:00:00          00:00:00             2:35:24
# 3          2:39:59          00:00:00          00:00:00             2:39:59
# 4          2:42:09          00:00:00          00:00:00             2:42:09
#
#   Transition1TimeConverted Transition2TimeConverted CountryISO2  \
# 0                 00:00:00                 00:00:00          US
# 1                 00:00:00                 00:00:00          US
# 2                 00:00:00                 00:00:00          US
# 3                 00:00:00                 00:00:00          US
# 4                 00:00:00                 00:00:00          US
#
#                             SubeventName  \
# 0  2019 Rock 'n' Roll Nashville Marathon
# 1  2019 Rock 'n' Roll Nashville Marathon
# ...

# %%
marathon2017.shape
# Out:
# (3651, 39)

# %%
marathon2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3651 entries, 0 to 3650
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   RunTimeConverted               3651 non-null   object
#  1   SwimTimeConverted              3651 non-null   object
#  2   BikeTimeConverted              3651 non-null   object
#  3   FinishTimeConverted            3651 non-null   object
#  4   Transition1TimeConverted       3651 non-null   object
#  5   Transition2TimeConverted       3651 non-null   object
#  6   CountryISO2                    3651 non-null   object
#  7   SubeventName                   3651 non-null   object
#  8   ResultId                       3651 non-null   object
#  9   ContactId                      3651 non-null   object
#  10  AgeGroup                       3651 non-null   object
#  11  CountryRepresentingISONumeric  3651 non-null   int64
# ...

# %%
marathon2017.isnull().sum()
# Out:
# RunTimeConverted                    0
# SwimTimeConverted                   0
# BikeTimeConverted                   0
# FinishTimeConverted                 0
# Transition1TimeConverted            0
# Transition2TimeConverted            0
# CountryISO2                         0
# SubeventName                        0
# ResultId                            0
# ContactId                           0
# AgeGroup                            0
# CountryRepresentingISONumeric       0
# BibNumber                           0
# EventStatus                         0
# SwimTime                            0
# Transition1Time                     0
# BikeTime                            0
# Transition2Time                     0
# RunTime                             0
# FinishTime                          0
# FinishRankGroup                     0
# FinishRankGender                    0
# FinishRankOverall                   0
# SwimRankGroup                       0
# SwimRankGender                      0
# ...

# %%
marathon2017.RunTimeConverted.value_counts()
# Out:
# 00:00:00    1056
# 5:10:10        5
# 5:13:01        5
# 5:02:29        4
# 4:47:07        4
#             ...
# 5:38:41        1
# 5:25:22        1
# 4:54:38        1
# 5:39:13        1
# 4:32:18        1
# Name: RunTimeConverted, Length: 2170, dtype: int64

# %%
marathon2017.RunRankGender.value_counts()
# Out:
# 99999    1185
# 826         2
# 812         2
# 814         2
# 816         2
#          ...
# 1270        1
# 1272        1
# 1274        1
# 1276        1
# 1210        1
# Name: RunRankGender, Length: 1329, dtype: int64

# %%
marathon2017.RunRankGroup.value_counts()
# Out:
# 99999    1186
# 1          23
# 2          21
# 5          21
# 3          21
#          ...
# 242         1
# 240         1
# 238         1
# 236         1
# 254         1
# Name: RunRankGroup, Length: 255, dtype: int64

# %%
marathon2017.EventStatus.value_counts()
# Out:
# Finish    2471
# DNS        982
# DNF        196
# DQ           2
# Name: EventStatus, dtype: int64

# %%
marathon2017.CountryISO2.value_counts()
# Out:
# US    3556
# CA      58
# GB       8
# CN       3
# DE       3
# CH       3
# MX       3
# SE       2
# AU       2
# BM       2
# ZZ       2
# IT       2
# NI       1
# IE       1
# IS       1
# AT       1
# BR       1
# ES       1
# ZA       1
# Name: CountryISO2, dtype: int64

# %%
marathon2017.describe()
# Out:
#        CountryRepresentingISONumeric      BibNumber  SwimTime  \
# count                    3651.000000    3651.000000    3651.0
# mean                     1372.539578   14918.875103       0.0
# std                     23382.696041    8697.259055       0.0
# min                        36.000000       1.000000       0.0
# 25%                       840.000000    7139.500000       0.0
# 50%                       840.000000   15104.000000       0.0
# 75%                       840.000000   23041.500000       0.0
# max                    999999.000000  111126.000000       0.0
#
#        Transition1Time  BikeTime  Transition2Time       RunTime    FinishTime  \
# count           3651.0    3651.0           3651.0   3651.000000   3651.000000
# mean               0.0       0.0              0.0  12529.074774  12529.074774
# std                0.0       0.0              0.0   8249.405819   8249.405819
# min                0.0       0.0              0.0      0.000000      0.000000
# ...

# %%
plt.hist('RunTime', bins = 10, data = marathon2017)
plt.title("Distribution of Runner's time");

# %%
plt.hist('RunTime', bins = 10, data = marathon2018)
plt.title("Distribution of Runner's time");

# %%
plt.hist('RunTime', bins = 10, data = marathon2019)
plt.title("Distribution of Runner's time");
